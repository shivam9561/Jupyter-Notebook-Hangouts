# %%
import pandas as pd
df = pd.read_csv("nba-2.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Applying groupby() function.
gk = df.groupby('Team')
gk.first()
# Out:
#                                          Name  Number Position  Age  Height  \
# Team
# Atlanta Hawks                   Kent Bazemore      24       SF   26   5-Jun
# Boston Celtics                  Avery Bradley       0       PG   25   2-Jun
# Brooklyn Nets                Bojan Bogdanovic      44       SG   27   8-Jun
# Charlotte Hornets               Nicolas Batum       5       SG   27   8-Jun
# Chicago Bulls                Cameron Bairstow      41       PF   25   9-Jun
# Cleveland Cavaliers       Matthew Dellavedova       8       PG   25   4-Jun
# Dallas Mavericks              Justin Anderson       1       SG   22   6-Jun
# Denver Nuggets                 Darrell Arthur       0       PF   28   9-Jun
# Detroit Pistons                  Joel Anthony      50        C   33   9-Jun
# Golden State Warriors         Leandro Barbosa      19       SG   33   3-Jun
# Houston Rockets                  Trevor Ariza       1       SF   30   8-Jun
# ...

# %%
#Finding the values contained in the "Boston Celtics" group
gk.get_group('Boston Celtics')
# Out:
#                Name            Team  Number Position  Age  Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2      John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5      Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# ...

# %%
import pandas as pd

#Creating the dataframe
df = pd.read_csv("nba-2.csv")

#First grouping based on "Team"
#Within each team we are grouping based on "Position"

gkk = df.groupby(['Team','Position'])

#Printing the first value in each group.
gkk.first()
# Out:
#                                          Name  Number  Age  Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford      15   30  10-Jun     245
#                    PF          Kris Humphries      43   31   9-Jun     235
#                    PG         Dennis Schroder      17   22   1-Jun     172
#                    SF           Kent Bazemore      24   26   5-Jun     201
#                    SG        Tim Hardaway Jr.      10   24   6-Jun     205
# ...                                       ...     ...  ...     ...     ...
# Washington Wizards C            Marcin Gortat      13   32  11-Jun     240
#                    PF             Drew Gooden      90   34  10-Jun     250
#                    PG          Ramon Sessions       7   30   3-Jun     190
#                    SF            Jared Dudley       1   30   7-Jun     225
#                    SG           Alan Anderson       6   33   6-Jun     220
#
# ...

# %%
import pandas as pd

#Creating the dataframe
df = pd.read_csv("nba-2.csv")

#First grouping based on "Team"
#Within each team we are grouping based on "Position"

gkk = df.groupby(['Salary','College'])

#Printing the first value in each group.
gkk.first()
# Out:
#                                         Name                   Team  Number  \
# Salary     College
# 55722.0    Missouri             Phil Pressey           Phoenix Suns      25
#            UC Santa Barbara  Orlando Johnson   New Orleans Pelicans       0
# 83397.0    UC Santa Barbara    Alan Williams           Phoenix Suns      15
# 111196.0   Tennessee            Jordan McRae    Cleveland Cavaliers      12
# 111444.0   Arizona State          Jeff Ayres   Los Angeles Clippers      19
# ...                                      ...                    ...     ...
# 20093064.0 Memphis              Derrick Rose          Chicago Bulls       1
# 20158622.0 Texas                Kevin Durant  Oklahoma City Thunder      35
# 21468695.0 Wake Forest            Chris Paul   Los Angeles Clippers       3
# 22192730.0 Georgia Tech           Chris Bosh             Miami Heat       1
# 22875000.0 Syracuse          Carmelo Anthony        New York Knicks       7
#
# ...

# %%
import pandas as pd

#Creating the dataframe
df = pd.read_csv("nba-2.csv")

#First grouping based on "Team"
#Within each team we are grouping based on "Position"

gkk = df.groupby(['Height','Weight'])

#Printing the first value in each group.
gkk.first()
# Out:
#                          Name                 Team  Number Position  Age  \
# Height Weight
# 1-Jul  240     Tyson Chandler         Phoenix Suns       4        C   33
#        245      Spencer Hawes    Charlotte Hornets       0       PF   28
#        255         Marc Gasol    Memphis Grizzlies      33        C   31
#        260           Alex Len         Phoenix Suns      21        C   22
#        275     Timofey Mozgov  Cleveland Cavaliers      20        C   29
# ...                       ...                  ...     ...      ...  ...
# Jun-00 183      D.J. Augustin       Denver Nuggets      12       PG   28
#        185         J.J. Barea     Dallas Mavericks       5       PG   31
#        190      Jameer Nelson       Denver Nuggets       1       PG   34
#        201      Isaiah Canaan   Philadelphia 76ers       0       PG   25
#        205         Kyle Lowry      Toronto Raptors       7       PG   30
#
#                       College      Salary
# Height Weight
# ...

# %%
import pandas as pd
import numpy as np

#Creating a Dataframe
df = pd.DataFrame({'A':['John','Boby','Mina','Peter','Nicky'],
                  'B':['Masters','Graduate','Graduate','Masters','Graduate'],
                  'C':[27,23,21,23,24]})
df
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
import pandas as pd
import numpy as np

#Creating a Dataframe
df = pd.DataFrame({'A':['Alex Len','Marc Gasol','Spencer Hawes','Tyson Chandler','Nicky'],
                  'B':['Masters','Graduate','Graduate','Masters','Graduate'],
                  'C':[27,23,21,23,24]})
df
# Out:
#                 A         B   C
# 0        Alex Len   Masters  27
# 1      Marc Gasol  Graduate  23
# 2   Spencer Hawes  Graduate  21
# 3  Tyson Chandler   Masters  23
# 4           Nicky  Graduate  24

# %%
import pandas as pd
import numpy as np

#Creating a Dataframe
df = pd.DataFrame({'A':['Alex Len','Marc Gasol','Spencer Hawes','Tyson Chandler','Nicky'],
                  'B':['Age','College','Graduate','Masters','Number'],
                  'C':[27,23,21,23,24]})
df
# Out:
#                 A         B   C
# 0        Alex Len       Age  27
# 1      Marc Gasol   College  23
# 2   Spencer Hawes  Graduate  21
# 3  Tyson Chandler   Masters  23
# 4           Nicky    Number  24

# %%
#Simplest pivot table must have a dataframe
#and an index/list of index.
table = pd.pivot_table(df,index = ['A','B'])
table
# Out:
#                           C
# A              B
# Alex Len       Age       27
# Marc Gasol     College   23
# Nicky          Number    24
# Spencer Hawes  Graduate  21
# Tyson Chandler Masters   23

# %%
#Simplest pivot table must have a dataframe
#and an index/list of index.
table = pd.pivot_table(df,index = ['A','B'])
table
# Out:
#                           C
# A              B
# Alex Len       Age       27
# Marc Gasol     College   23
# Nicky          Number    24
# Spencer Hawes  Graduate  21
# Tyson Chandler Masters   23

# %%
import pandas as pd
import numpy as np

#Creating a Dataframe
df = pd.DataFrame({'A':['John','Boby','Mina','Peter','Nicky'],
                  'B':['Masters','Graduate','Graduate','Masters','Graduate'],
                  'C':[27,23,21,23,24]})
df
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24
